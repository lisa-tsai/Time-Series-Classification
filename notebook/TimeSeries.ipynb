# %% [markdown]
# Name: Tsai, Yu-Yun

# %%
import numpy as np
import pandas as pd
import os
import glob

# %% [markdown]
# 1. Time Series Classification Part 1: Feature Creation/Extraction
# An interesting task in machine learning is classification of time series. In this problem, we will classify the activities of humans based on time series obtained by a Wireless Sensor Network.
# (a) Download the AReM data from: https://archive.ics.uci.edu/ml/datasets/ Activity+Recognition+system+based+on+Multisensor+data+fusion+\%28AReM\ %29 . The dataset contains 7 folders that represent seven types of activities. In each folder, there are multiple files each of which represents an instant of a human performing an activity.1 Each file containis 6 time series collected from activities
# of the same person, which are called avg rss12, var rss12, avg rss13, var rss13, vg rss23, and ar rss23. There are 88 instances in the dataset, each of which con- tains 6 time series and each time series has 480 consecutive values.

# %%
col_names = ['time','avg_RSS12', 'var_RSS12', 'avg_RSS13', 'var_RSS13', 'avg_RSS23', 'var_RSS23']

# %%
loc = os.getcwd()
all_files = glob.glob(os.path.join(loc,'../data/AReM', "**/*.csv"))

data_dict={}

for files in all_files:
    
        df = pd.read_csv(files, skiprows=5, names = col_names)
        data_dict[files] = df

    #print(files)
    
data_dict
# Out:
# {'/Users/yuyun/Documents/USC class/Spring 2022/DSCI552/HW3/notebook/../data/AReM/bending1/dataset7.csv':        time  avg_RSS12  var_RSS12  avg_RSS13  var_RSS13  avg_RSS23  var_RSS23
#  0         0      42.00       0.00      18.50       0.50      12.00       0.00
#  1       250      42.00       0.00      18.00       0.00      11.33       0.94
#  2       500      42.75       0.43      16.75       1.79      18.25       0.43
#  3       750      42.50       0.50      16.75       0.83      19.00       1.22
#  4      1000      43.00       0.82      16.25       0.83      18.00       0.00
#  ..      ...        ...        ...        ...        ...        ...        ...
#  475  118750      44.25       0.83      16.25       1.30      24.00       0.00
#  476  119000      44.00       0.71      11.00       1.00      24.00       0.00
#  477  119250      44.25       0.43      10.25       1.30      22.75       0.83
#  478  119500      43.75       0.43       7.33       2.87      21.50       0.50
# ...

# %% [markdown]
# (b) Keep datasets 1 and 2 in folders bending1 and bending 2, as well as datasets 1, 2, and 3 in other folders as test data and other datasets as train data.

# %%
testset = []
trainset = []

#split the data to train and test set 
for filename in data_dict:
    
    if filename.endswith("dataset1.csv") or filename.endswith("dataset2.csv"):   
        testset.append(data_dict[(filename)])
    elif  filename.endswith("walking/dataset3.csv") or filename.endswith("cycling/dataset3.csv") or filename.endswith("sitting/dataset3.csv"):   
        testset.append(data_dict[(filename)]) 
    elif  filename.endswith("lying/dataset3.csv") or filename.endswith("standing/dataset3.csv"):   
        testset.append(data_dict[(filename)])
    else:
        trainset.append(data_dict[(filename)])
    
   
print(len(testset))
#print(trainset)
# Out:
# 19

# %%
col_names = ['time','avg_rss12', 'var_rss12', 'avg_rss13', 'var_rss13', 'avg_rss23', 'var_rss23']
#convert testset to dataframe
df_test = pd.DataFrame(np.concatenate(testset), columns = col_names)
df_test
# Out:
#           time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0          0.0      39.25       0.43      22.75       0.43      33.75
# 1        250.0      39.25       0.43      23.00       0.00      33.00
# 2        500.0      39.25       0.43      23.25       0.43      33.00
# 3        750.0      39.50       0.50      23.00       0.71      33.00
# 4       1000.0      39.50       0.50      24.00       0.00      33.00
# ...        ...        ...        ...        ...        ...        ...
# 9115  118750.0      36.50       1.50      15.67       9.74      20.50
# 9116  119000.0      36.00       0.00      23.25       1.30      17.00
# 9117  119250.0      32.33       5.56      15.33       3.77      14.50
# 9118  119500.0      32.00       5.87      12.25       2.17      14.50
# 9119  119750.0      38.00       2.12      16.50       3.20      11.25
#
#       var_rss23
# 0          1.30
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# ...         ...
# ...

# %%
#convert trainset to dataframe
df_train = pd.DataFrame(np.concatenate(trainset), columns = col_names)
df_train
# Out:
#            time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0           0.0      42.00       0.00      18.50       0.50      12.00
# 1         250.0      42.00       0.00      18.00       0.00      11.33
# 2         500.0      42.75       0.43      16.75       1.79      18.25
# 3         750.0      42.50       0.50      16.75       0.83      19.00
# 4        1000.0      43.00       0.82      16.25       0.83      18.00
# ...         ...        ...        ...        ...        ...        ...
# 33114  118750.0      41.75       1.79      11.00       6.00      16.67
# 33115  119000.0      36.33       0.47      16.00       3.16      20.33
# 33116  119250.0      31.50       1.50      21.00       0.00      12.25
# 33117  119500.0      34.25       6.38      12.67       2.49      15.25
# 33118  119750.0      38.33       0.94      15.25       2.17      20.33
#
#        var_rss23
# 0           0.00
# 1           0.94
# 2           0.43
# 3           1.22
# 4           0.00
# ...

# %% [markdown]
# (c) Feature Extraction
# Classification of time series usually needs extracting features from them. In this problem, we focus on time-domain features.
#
# i. Research what types of time-domain features are usually used in time series classification and list them (examples are minimum, maximum, mean, etc).

# %% [markdown]
# Ans:
#
# 1. Maximum value
#
# 2. Minimum value
#
# 3. Mean value
#
# 4. Median
#
# 5. Standard Deviation
#
# 6. Range
#
# 7. First Quartile/Third Quartile/Interquartile
#
# 8. Coefficient of Skewness
#
# 9. Coefficient of Kurtosis

# %% [markdown]
# ii. Extract the time-domain features minimum, maximum, mean, median, standard deviation, first quartile, and third quartile for all of the 6 time series in each instance. You are free to normalize/standardize features or use them directly. where, for example, 1st quart6, means the first quartile of the sixth time series in each of the 88 instances.

# %%
features=['Min','Max','Mean','Median','Std','1st_quart','3rd_quart']
#create a dictionary
col={}

#create lists for features
for k in range(1,7,1):
    for feat in features:
        col[feat+str(k)]=[]
        col[feat+str(k)]=[]
        col[feat+str(k)]=[]
        col[feat+str(k)]=[]
        col[feat+str(k)]=[]
        col[feat+str(k)]=[]
        col[feat+str(k)]=[]

for files in data_dict:
     for k in range(1,7,1): 
                    col['Min'+str(k)].append((np.min(data_dict[files].iloc[:,k])))
                    col['Max'+str(k)].append((np.max(data_dict[files].iloc[:,k])))
                    col['Mean'+str(k)].append((np.mean(data_dict[files].iloc[:,k])))
                    col['Median'+str(k)].append((np.median(data_dict[files].iloc[:,k])))
                    col['Std'+str(k)].append((np.std(data_dict[files].iloc[:,k])))
                    col['1st_quart'+str(k)].append((np.quantile(data_dict[files].iloc[:,k],0.25)))
                    col['3rd_quart'+str(k)].append((np.quantile(data_dict[files].iloc[:,k],0.75))) 
#print(col)
#convert to a dataframe
df_features = pd.DataFrame(col)
df_features
# Out:
#      Min1   Max1      Mean1  Median1      Std1  1st_quart1  3rd_quart1  Min2  \
# 0   36.25  48.00  43.969125    44.50  1.616677     43.3100       44.67   0.0
# 1   37.00  48.00  43.454958    43.25  1.384653     42.5000       45.00   0.0
# 2   33.00  47.75  42.179813    43.50  3.666840     39.1500       45.00   0.0
# 3   33.00  45.75  41.678063    41.75  2.241152     41.3300       42.75   0.0
# 4   37.25  45.00  40.624792    40.50  1.475428     39.2500       42.00   0.0
# ..    ...    ...        ...      ...       ...         ...         ...   ...
# 83  18.50  44.25  35.752354    36.00  4.609992     33.0000       39.33   0.0
# 84  24.25  45.00  37.177042    36.25  3.577569     34.5000       40.25   0.0
# 85  23.33  43.50  36.244083    36.75  3.818032     33.4575       39.25   0.0
# 86  26.25  44.25  36.957458    36.29  3.431283     34.5000       40.25   0.0
# 87  27.75  44.67  37.144833    36.33  3.754986     34.0000       40.50   0.0
#
# ...

# %% [markdown]
# iii. Estimate the standard deviation of each of the time-domain features you extracted from the data. Then, use Python’s bootstrapped or any other method to build a 90% bootsrap confidence interval for the standard deviation of each feature.

# %%
#Estimate the standard deviation
df_std = np.std(df_features)

df_std
# Out:
# Min1          9.515445
# Max1          4.369322
# Mean1         5.305314
# Median1       5.409056
# Std1          1.760219
# 1st_quart1    6.118526
# 3rd_quart1    5.109643
# Min2          0.000000
# Max2          5.033882
# Mean2         1.565194
# Median2       1.404197
# Std2          0.878152
# 1st_quart2    0.940994
# 3rd_quart2    2.113157
# Min3          2.939616
# Max3          4.847358
# Mean3         3.985540
# Median3       4.013397
# Std3          0.940335
# 1st_quart3    4.196608
# 3rd_quart3    4.147858
# Min4          0.000000
# Max4          2.171183
# Mean4         1.159470
# Median4       1.139058
# Std4          0.455156
# 1st_quart4    0.838813
# 3rd_quart4    1.543658
# Min5          6.089107
# Max5          5.708524
# Mean5         5.643253
# Median5       5.780655
# Std5          1.017996
# 1st_quart5    6.061727
# 3rd_quart5    5.500200
# Min6          0.045577
# Max6          2.504568
# Mean6         1.148232
# Median6       1.080284
# Std6          0.514132
# ...

# %%
#build a 90% bootsrap confidence interval for the standard deviation of each feature.
import numpy as np
import bootstrapped.bootstrap as bs
import bootstrapped.stats_functions as bs_stats
from scipy.stats import bootstrap

# %%
features=['Min','Max','Mean','Median','Std','1st_quart','3rd_quart']
#create a list
col_n=[]

for k in range(1,7,1):
    for feat in features:
        col_n.append(feat+str(k))

interval_lower = []
interval_upper = []

for columns in col_n:
    bt = bootstrap((df_features[columns].to_numpy(),), np.std, confidence_level = 0.9, method='Percentile', 
                   random_state=42)
    interval_lower.append(bt.confidence_interval[0])      
    interval_upper.append(bt.confidence_interval[1])
list_std = list(df_std)
df_bt_interval = pd.DataFrame()
df_bt_interval = df_bt_interval.assign(Features = col_n, standard_deviation = list_std, lower_interval = interval_lower, upper_interval = interval_upper)
df_bt_interval
# Out:
#       Features  standard_deviation  lower_interval  upper_interval
# 0         Min1            9.515445        8.194159       10.709340
# 1         Max1            4.369322        3.326441        5.262996
# 2        Mean1            5.305314        4.678608        5.845132
# 3      Median1            5.409056        4.761006        5.969593
# 4         Std1            1.760219        1.556206        1.933971
# 5   1st_quart1            6.118526        5.535468        6.611138
# 6   3rd_quart1            5.109643        4.310269        5.806589
# 7         Min2            0.000000        0.000000        0.000000
# 8         Max2            5.033882        4.603680        5.379297
# 9        Mean2            1.565194        1.387320        1.699170
# 10     Median2            1.404197        1.227283        1.537033
# 11        Std2            0.878152        0.797723        0.936198
# 12  1st_quart2            0.940994        0.824366        1.030863
# ...

# %% [markdown]
# iv. Use your judgement to select the three most important time-domain features (one option may be min, mean, and max).

# %% [markdown]
# Ans:
#
# I would select min, max, mean as the three most important time-domain.
# Through min and max, we can obtain the range of the data. For mean, we can know the center of the data.

# %% [markdown]
# 2. ISLR 3.7.4

# %% [markdown]
# 4.
# I collect a set of data (n = 100 observations) containing a single predictor and a quantitative response. I then fit a linear regression model to the data, as well as a separate cubic regression, i.e. Y = β0 +β1X +β2X2 +β3X3 +ε.
#
# (a) Suppose that the true relationship between X and Y is linear, i.e. Y = β0 + β1X + ε. Consider the training residual sum of squares (RSS) for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.

# %% [markdown]
# Ans: I think cubic regression would have a lower training RSS than the linear regression, because of the irreducible error it would fit the model better.

# %% [markdown]
# (b) Answer (a) using test rather than training RSS.

# %% [markdown]
# Ans:  Cubic regression would have a higher test RSS than the linear regression, because the model might be overfit from training, which would have more test error.

# %% [markdown]
# (c) Suppose that the true relationship between X and Y is not linear, but we don’t know how far it is from linear. Consider the training RSS for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.

# %% [markdown]
# Training RSS of cubic regression would be lower than the linear regression, because the model is more flexible than linear. In this case, it is likely to be closer to the observed points and thus reduce the training RSS.

# %% [markdown]
# (d) Answer (c) using test rather than training RSS.

# %% [markdown]
# Ans: We do not have enough information to tell which test RSS would be lower for these two regression, since we are not sure about how far it is from linear. If it is closer to cubic regression, the test RSS of cubic might be lower than the linear regression because of bias-variance.
